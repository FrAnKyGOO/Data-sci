# %% [markdown]
# **JSON (JavaScript Object Notation) is lightweight format for storing and transporting data.**

# %% [markdown]
# **JSON used to create objects to send data between an application or an Applications Program Interface (API).**

# %% [markdown]
# ----

# %% [markdown]
# ### Read JSON from URL use pandas.read_json()

# %%
import pandas as pd

# %%
#https://github.com/mathawanup/master_dataset/blob/master/NineTemples.json
url = 'https://github.com/mathawanup/master_dataset/raw/master/NineTemples.json'
df = pd.read_json(url)
df
# Out:
#                                    belief        lat         lon  \
# 0       เดินทางปลอดภัยดี มีมิตรไมตรีที่ดี  13.739810  100.489057
# 1               มีชัยชนะต่ออุปสรรคทั้งปวง  13.760404  100.493371
# 2                          ร่มเย็นเป็นสุข  13.746527  100.491105
# 3             เพื่อจิตใจสะอาด ดุจรัตนตรัย  13.751502  100.490475
# 4            ชื่อเสียงโด่งดัง คนนิยมชมชอบ  13.752310  100.483130
# 5  วิสัยทัศน์กว้างไกล มีเสน่ห์แก่คนทั่วไป  13.750034  100.498670
# 6                 ชีวิตรุ่งโรจน์ทุกคืนวัน  13.743691  100.486733
# 7                   พบแต่สิ่งดีงามในชีวิต  13.759537  100.497773
# 8        เสริมสร้างความคิดอันเป็นสิริมงคล  13.753805  100.504475
#
#                           watEn                                   watTh
# 0              Wat Kalayanamitr                 วัดกัลยาณมิตรวรมหาวิหาร
# 1           Wat Chana Songkhram               วัดชนะสงครามราชวรมหาวิหาร
# 2            Wat Phra Chetuphon  วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร
# 3  Temple of the Emerald Buddha                   วัดพระศรีรัตนศาสดาราม
# 4        Wat Rakhang Khositaram             วัดระฆังโฆสิตารามวรมหาวิหาร
# 5        Wat Suthat Thepwararam         วัดสุทัศนเทพวรารามราชวรมหาวิหาร
# 6                      Wat Arun           วัดอรุณราชวรารามราชวรมหาวิหาร
# 7              Wat Bavorn Niwet                        วัดบวรนิเวศวิหาร
# 8                    Wat Sa Ket                  วัดสระเกศราชวรมหาวิหาร

# %%
df.columns
# Out:
# Index(['belief', 'lat', 'lon', 'watEn', 'watTh'], dtype='object')

# %%
df = df[['watTh', 'watEn', 'lat', 'lon', 'belief']]
df
# Out:
#                                     watTh                         watEn  \
# 0                 วัดกัลยาณมิตรวรมหาวิหาร              Wat Kalayanamitr
# 1               วัดชนะสงครามราชวรมหาวิหาร           Wat Chana Songkhram
# 2  วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร            Wat Phra Chetuphon
# 3                   วัดพระศรีรัตนศาสดาราม  Temple of the Emerald Buddha
# 4             วัดระฆังโฆสิตารามวรมหาวิหาร        Wat Rakhang Khositaram
# 5         วัดสุทัศนเทพวรารามราชวรมหาวิหาร        Wat Suthat Thepwararam
# 6           วัดอรุณราชวรารามราชวรมหาวิหาร                      Wat Arun
# 7                        วัดบวรนิเวศวิหาร              Wat Bavorn Niwet
# 8                  วัดสระเกศราชวรมหาวิหาร                    Wat Sa Ket
#
#          lat         lon                                  belief
# 0  13.739810  100.489057       เดินทางปลอดภัยดี มีมิตรไมตรีที่ดี
# 1  13.760404  100.493371               มีชัยชนะต่ออุปสรรคทั้งปวง
# 2  13.746527  100.491105                          ร่มเย็นเป็นสุข
# 3  13.751502  100.490475             เพื่อจิตใจสะอาด ดุจรัตนตรัย
# 4  13.752310  100.483130            ชื่อเสียงโด่งดัง คนนิยมชมชอบ
# 5  13.750034  100.498670  วิสัยทัศน์กว้างไกล มีเสน่ห์แก่คนทั่วไป
# 6  13.743691  100.486733                 ชีวิตรุ่งโรจน์ทุกคืนวัน
# 7  13.759537  100.497773                   พบแต่สิ่งดีงามในชีวิต
# 8  13.753805  100.504475        เสริมสร้างความคิดอันเป็นสิริมงคล

# %% [markdown]
# ---

# %% [markdown]
# ## Read JSON from URL use OrderedDict

# %%
from collections import OrderedDict
import json
import requests

# %%
url = 'https://github.com/mathawanup/master_dataset/raw/master/NineTemples.json'
r = requests.get(url)
r.text
# Out:
# '[{"watTh":"วัดกัลยาณมิตรวรมหาวิหาร","watEn":"Wat Kalayanamitr","lat":13.7398104,"lon":100.4890565,"belief":"เดินทางปลอดภัยดี มีมิตรไมตรีที่ดี"},\n {"watTh":"วัดชนะสงครามราชวรมหาวิหาร","watEn":"Wat Chana Songkhram","lat":13.760404,"lon":100.4933709,"belief":"มีชัยชนะต่ออุปสรรคทั้งปวง"},\n {"watTh":"วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร","watEn":"Wat Phra Chetuphon","lat":13.7465275,"lon":100.4911048,"belief":"ร่มเย็นเป็นสุข"},\n {"watTh":"วัดพระศรีรัตนศาสดาราม","watEn":"Temple of the Emerald Buddha","lat":13.7515019,"lon":100.4904745,"belief":"เพื่อจิตใจสะอาด ดุจรัตนตรัย"},\n {"watTh":"วัดระฆังโฆสิตารามวรมหาวิหาร","watEn":"Wat Rakhang Khositaram","lat":13.7523101,"lon":100.4831296,"belief":"ชื่อเสียงโด่งดัง คนนิยมชมชอบ"},\n {"watTh":"วัดสุทัศนเทพวรารามราชวรมหาวิหาร","watEn":"Wat Suthat Thepwararam","lat":13.7500342,"lon":100.4986696,"belief":"วิสัยทัศน์กว้างไกล มีเสน่ห์แก่คนทั่วไป"},\n {"watTh":"วัดอรุณราชวรารามราชวรมหาวิหาร","watEn":"Wat Arun","lat":13.7436906,"lon":100.4867328,"belief":"ชีวิตรุ่งโรจน์ทุกคืนวัน"},\n {"watTh":"วัดบวรนิเวศวิหาร","watEn":"Wat Bavorn Niwet","lat":13.7595372,"lon":100.4977729,"belief":"พบแต่สิ่งดีงามในชีวิต"},\n {"watTh":"วัดสระเกศราชวรมหาวิหาร","watEn":"Wat Sa Ket","lat":13.7538052,"lon":100.5044746,"belief":"เสริมสร้างความคิดอันเป็นสิริมงคล"}\n]\n'

# %%
j = json.loads(r.text, object_pairs_hook=OrderedDict)
print(json.dumps(j, indent=2, sort_keys=False))
# Out:
# [
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e01\u0e31\u0e25\u0e22\u0e32\u0e13\u0e21\u0e34\u0e15\u0e23\u0e27\u0e23\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Kalayanamitr",
#     "lat": 13.7398104,
#     "lon": 100.4890565,
#     "belief": "\u0e40\u0e14\u0e34\u0e19\u0e17\u0e32\u0e07\u0e1b\u0e25\u0e2d\u0e14\u0e20\u0e31\u0e22\u0e14\u0e35 \u0e21\u0e35\u0e21\u0e34\u0e15\u0e23\u0e44\u0e21\u0e15\u0e23\u0e35\u0e17\u0e35\u0e48\u0e14\u0e35"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e0a\u0e19\u0e30\u0e2a\u0e07\u0e04\u0e23\u0e32\u0e21\u0e23\u0e32\u0e0a\u0e27\u0e23\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Chana Songkhram",
#     "lat": 13.760404,
#     "lon": 100.4933709,
#     "belief": "\u0e21\u0e35\u0e0a\u0e31\u0e22\u0e0a\u0e19\u0e30\u0e15\u0e48\u0e2d\u0e2d\u0e38\u0e1b\u0e2a\u0e23\u0e23\u0e04\u0e17\u0e31\u0e49\u0e07\u0e1b\u0e27\u0e07"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e1e\u0e23\u0e30\u0e40\u0e0a\u0e15\u0e38\u0e1e\u0e19\u0e27\u0e34\u0e21\u0e25\u0e21\u0e31\u0e07\u0e04\u0e25\u0e32\u0e23\u0e32\u0e21\u0e23\u0e32\u0e0a\u0e27\u0e23\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Phra Chetuphon",
#     "lat": 13.7465275,
#     "lon": 100.4911048,
#     "belief": "\u0e23\u0e48\u0e21\u0e40\u0e22\u0e47\u0e19\u0e40\u0e1b\u0e47\u0e19\u0e2a\u0e38\u0e02"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e1e\u0e23\u0e30\u0e28\u0e23\u0e35\u0e23\u0e31\u0e15\u0e19\u0e28\u0e32\u0e2a\u0e14\u0e32\u0e23\u0e32\u0e21",
#     "watEn": "Temple of the Emerald Buddha",
#     "lat": 13.7515019,
#     "lon": 100.4904745,
#     "belief": "\u0e40\u0e1e\u0e37\u0e48\u0e2d\u0e08\u0e34\u0e15\u0e43\u0e08\u0e2a\u0e30\u0e2d\u0e32\u0e14 \u0e14\u0e38\u0e08\u0e23\u0e31\u0e15\u0e19\u0e15\u0e23\u0e31\u0e22"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e23\u0e30\u0e06\u0e31\u0e07\u0e42\u0e06\u0e2a\u0e34\u0e15\u0e32\u0e23\u0e32\u0e21\u0e27\u0e23\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Rakhang Khositaram",
#     "lat": 13.7523101,
#     "lon": 100.4831296,
#     "belief": "\u0e0a\u0e37\u0e48\u0e2d\u0e40\u0e2a\u0e35\u0e22\u0e07\u0e42\u0e14\u0e48\u0e07\u0e14\u0e31\u0e07 \u0e04\u0e19\u0e19\u0e34\u0e22\u0e21\u0e0a\u0e21\u0e0a\u0e2d\u0e1a"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e2a\u0e38\u0e17\u0e31\u0e28\u0e19\u0e40\u0e17\u0e1e\u0e27\u0e23\u0e32\u0e23\u0e32\u0e21\u0e23\u0e32\u0e0a\u0e27\u0e23\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Suthat Thepwararam",
#     "lat": 13.7500342,
#     "lon": 100.4986696,
#     "belief": "\u0e27\u0e34\u0e2a\u0e31\u0e22\u0e17\u0e31\u0e28\u0e19\u0e4c\u0e01\u0e27\u0e49\u0e32\u0e07\u0e44\u0e01\u0e25 \u0e21\u0e35\u0e40\u0e2a\u0e19\u0e48\u0e2b\u0e4c\u0e41\u0e01\u0e48\u0e04\u0e19\u0e17\u0e31\u0e48\u0e27\u0e44\u0e1b"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e2d\u0e23\u0e38\u0e13\u0e23\u0e32\u0e0a\u0e27\u0e23\u0e32\u0e23\u0e32\u0e21\u0e23\u0e32\u0e0a\u0e27\u0e23\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Arun",
#     "lat": 13.7436906,
#     "lon": 100.4867328,
#     "belief": "\u0e0a\u0e35\u0e27\u0e34\u0e15\u0e23\u0e38\u0e48\u0e07\u0e42\u0e23\u0e08\u0e19\u0e4c\u0e17\u0e38\u0e01\u0e04\u0e37\u0e19\u0e27\u0e31\u0e19"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e1a\u0e27\u0e23\u0e19\u0e34\u0e40\u0e27\u0e28\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Bavorn Niwet",
#     "lat": 13.7595372,
#     "lon": 100.4977729,
#     "belief": "\u0e1e\u0e1a\u0e41\u0e15\u0e48\u0e2a\u0e34\u0e48\u0e07\u0e14\u0e35\u0e07\u0e32\u0e21\u0e43\u0e19\u0e0a\u0e35\u0e27\u0e34\u0e15"
#   },
#   {
#     "watTh": "\u0e27\u0e31\u0e14\u0e2a\u0e23\u0e30\u0e40\u0e01\u0e28\u0e23\u0e32\u0e0a\u0e27\u0e23\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e2b\u0e32\u0e23",
#     "watEn": "Wat Sa Ket",
#     "lat": 13.7538052,
#     "lon": 100.5044746,
#     "belief": "\u0e40\u0e2a\u0e23\u0e34\u0e21\u0e2a\u0e23\u0e49\u0e32\u0e07\u0e04\u0e27\u0e32\u0e21\u0e04\u0e34\u0e14\u0e2d\u0e31\u0e19\u0e40\u0e1b\u0e47\u0e19\u0e2a\u0e34\u0e23\u0e34\u0e21\u0e07\u0e04\u0e25"
#   }
# ]

# %%
df = pd.DataFrame(j)
df
# Out:
#                                     watTh                         watEn  \
# 0                 วัดกัลยาณมิตรวรมหาวิหาร              Wat Kalayanamitr
# 1               วัดชนะสงครามราชวรมหาวิหาร           Wat Chana Songkhram
# 2  วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร            Wat Phra Chetuphon
# 3                   วัดพระศรีรัตนศาสดาราม  Temple of the Emerald Buddha
# 4             วัดระฆังโฆสิตารามวรมหาวิหาร        Wat Rakhang Khositaram
# 5         วัดสุทัศนเทพวรารามราชวรมหาวิหาร        Wat Suthat Thepwararam
# 6           วัดอรุณราชวรารามราชวรมหาวิหาร                      Wat Arun
# 7                        วัดบวรนิเวศวิหาร              Wat Bavorn Niwet
# 8                  วัดสระเกศราชวรมหาวิหาร                    Wat Sa Ket
#
#          lat         lon                                  belief
# 0  13.739810  100.489057       เดินทางปลอดภัยดี มีมิตรไมตรีที่ดี
# 1  13.760404  100.493371               มีชัยชนะต่ออุปสรรคทั้งปวง
# 2  13.746527  100.491105                          ร่มเย็นเป็นสุข
# 3  13.751502  100.490475             เพื่อจิตใจสะอาด ดุจรัตนตรัย
# 4  13.752310  100.483130            ชื่อเสียงโด่งดัง คนนิยมชมชอบ
# 5  13.750034  100.498670  วิสัยทัศน์กว้างไกล มีเสน่ห์แก่คนทั่วไป
# 6  13.743691  100.486733                 ชีวิตรุ่งโรจน์ทุกคืนวัน
# 7  13.759537  100.497773                   พบแต่สิ่งดีงามในชีวิต
# 8  13.753805  100.504475        เสริมสร้างความคิดอันเป็นสิริมงคล

# %% [markdown]
# ---

# %% [markdown]
# ## Read JSON from REST API (Applications Program Interface )

# %%
# COVID-19 API  
# https://corona.lmao.ninja/docs/

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### Get global COVID-19 totals

# %%
url='https://disease.sh/v3/covid-19/all'
r=requests.get(url)
j=r.json()

# %%
type(j)
# Out:
# dict

# %%
j['cases']
# Out:
# 68017832

# %%
j['todayCases']
# Out:
# 84036

# %%
j['updated'] #Unix Timestamp  13 หลัก
# Out:
# 1607423907905

# %%
type(j['updated'])# 13 หลัก
# Out:
# int

# %%
#https://www.epochconverter.com/

# %%
j['updated'] // 1000
# Out:
# 1607423907

# %%
pd.datetime.fromtimestamp(j['updated'] // 1000).strftime('%Y-%m-%d %H:%M:%S') #เอาออก 3 หลัก
# Out:
# '2020-12-08 17:38:27'

# %% [markdown]
# ### Get COVID-19 totals for country

# %%
url='https://disease.sh/v3/covid-19/countries'
r=requests.get(url)
j=r.json()

# %%
df=pd.DataFrame(j)
df
# Out:
#       active  activePerOneMillion     cases  casesPerOneMillion  \
# 0       8422               214.27     48363                1230
# 1      20581              7155.08     43683               15187
# 2      28650               648.30     88825                2010
# 3        713              9221.54      7084               91620
# 4       6941               208.43     15648                 470
# 5          7               464.78        10                 664
# 6          8                81.40       146                1486
# 7     125725              2770.73   1466309               32315
# 8      21409              7218.95    142928               48194
# 9        120              1121.87      4966               46427
# 10      1433                55.91     27987                1092
# 11     44985              4982.38    305693               33857
# 12     57812              5679.58    149765               14713
# 13      1413              3578.33      7579               19193
# 14      1555               900.58     88111               51030
# 15     73845               446.46    481945                2914
# 16        20                69.56       287                 998
# 17     21654              2291.92    148953               15766
# 18    535291             46099.47    592615               51036
# 19      3834              9567.28      7953               19846
# 20       107                 8.73      3073                 251
# 21        75              1206.23       306                4921
# 22        42                54.17       432                 557
# 23     11679               994.64    145657               12405
# 24     32444              9916.17     94944               29019
# 25      2622              1105.37     12058                5083
# 26    649610              3046.70   6628065               31086
# 27         0                 0.00        72                2375
# 28         2                 4.55       152                 346
# 29     93559             13509.59    164185               23708
# ..       ...                  ...       ...                 ...
# 190       -6               -10.19      5325                9042
# 191      312               267.72      6529                5602
# 192   271845             26844.32    278912               27542
# 193    68911              7937.05    354306               40808
# 194     4038               228.36      8490                 480
# 195      129                 5.41       718                  30
# 196      501                52.03     12469                1295
# 197      305                 5.04       509                   8
# 198      192                 2.75      4126                  59
# 199        1                 0.75        31                  23
# 200      369                44.13      3111                 372
# 201      691               493.05      6775                4834
# 202    22935              1931.80    104329                8788
# 203   409059              4827.61    860432               10155
# 204       10               256.78       756               19412
# 205    17946              1805.03    178837               17988
# 206  1676526             24639.71   1737960               25543
# 207  6096224             18370.46  15370339               46317
# 208    13619               293.79     23200                 500
# 209   382266              8763.95    832758               19092
# 210     2182               627.19      7505                2157
# 211     2113                62.74     74206                2203
# 212        0                 0.00         1                   3
# 213     3998               140.77    104904                3694
# 214      108                 1.11      1367                  14
# 215        2               179.34         3                 269
# 216        1                 1.66        10                  17
# 217      180                 5.98      2383                  79
# 218      356                19.14     17931                 964
# 219     1573               105.17     10839                 725
#
#              continent                   country  \
# 0                 Asia               Afghanistan
# 1               Europe                   Albania
# 2               Africa                   Algeria
# 3               Europe                   Andorra
# 4               Africa                    Angola
# 5        North America                  Anguilla
# 6        North America       Antigua and Barbuda
# 7        South America                 Argentina
# 8                 Asia                   Armenia
# 9        North America                     Aruba
# 10   Australia/Oceania                 Australia
# 11              Europe                   Austria
# 12                Asia                Azerbaijan
# 13       North America                   Bahamas
# 14                Asia                   Bahrain
# 15                Asia                Bangladesh
# 16       North America                  Barbados
# 17              Europe                   Belarus
# 18              Europe                   Belgium
# 19       North America                    Belize
# 20              Africa                     Benin
# 21       North America                   Bermuda
# 22                Asia                    Bhutan
# 23       South America                   Bolivia
# 24              Europe                    Bosnia
# 25              Africa                  Botswana
# 26       South America                    Brazil
# 27       North America    British Virgin Islands
# 28                Asia                    Brunei
# 29              Europe                  Bulgaria
# ..                 ...                       ...
# 190      South America                  Suriname
# 191             Africa                 Swaziland
# 192             Europe                    Sweden
# 193             Europe               Switzerland
# 194               Asia      Syrian Arab Republic
# 195               Asia                    Taiwan
# 196               Asia                Tajikistan
# 197             Africa                  Tanzania
# 198               Asia                  Thailand
# 199               Asia               Timor-Leste
# 200             Africa                      Togo
# 201      North America       Trinidad and Tobago
# 202             Africa                   Tunisia
# 203               Asia                    Turkey
# 204      North America  Turks and Caicos Islands
# 205               Asia                       UAE
# 206             Europe                        UK
# 207      North America                       USA
# 208             Africa                    Uganda
# 209             Europe                   Ukraine
# 210      South America                   Uruguay
# 211               Asia                Uzbekistan
# 212  Australia/Oceania                   Vanuatu
# 213      South America                 Venezuela
# 214               Asia                   Vietnam
# 215  Australia/Oceania         Wallis and Futuna
# 216             Africa            Western Sahara
# 217               Asia                     Yemen
# 218             Africa                    Zambia
# 219             Africa                  Zimbabwe
#
#                                            countryInfo  critical  \
# 0    {'_id': 4, 'iso2': 'AF', 'iso3': 'AFG', 'lat':...        93
# 1    {'_id': 8, 'iso2': 'AL', 'iso3': 'ALB', 'lat':...        35
# 2    {'_id': 12, 'iso2': 'DZ', 'iso3': 'DZA', 'lat'...        46
# 3    {'_id': 20, 'iso2': 'AD', 'iso3': 'AND', 'lat'...        20
# 4    {'_id': 24, 'iso2': 'AO', 'iso3': 'AGO', 'lat'...        14
# 5    {'_id': 660, 'iso2': 'AI', 'iso3': 'AIA', 'lat...         0
# 6    {'_id': 28, 'iso2': 'AG', 'iso3': 'ATG', 'lat'...         2
# 7    {'_id': 32, 'iso2': 'AR', 'iso3': 'ARG', 'lat'...      3723
# 8    {'_id': 51, 'iso2': 'AM', 'iso3': 'ARM', 'lat'...         0
# 9    {'_id': 533, 'iso2': 'AW', 'iso3': 'ABW', 'lat...         4
# 10   {'_id': 36, 'iso2': 'AU', 'iso3': 'AUS', 'lat'...         0
# 11   {'_id': 40, 'iso2': 'AT', 'iso3': 'AUT', 'lat'...       616
# 12   {'_id': 31, 'iso2': 'AZ', 'iso3': 'AZE', 'lat'...         0
# 13   {'_id': 44, 'iso2': 'BS', 'iso3': 'BHS', 'lat'...        11
# 14   {'_id': 48, 'iso2': 'BH', 'iso3': 'BHR', 'lat'...        11
# 15   {'_id': 50, 'iso2': 'BD', 'iso3': 'BGD', 'lat'...         0
# 16   {'_id': 52, 'iso2': 'BB', 'iso3': 'BRB', 'lat'...         1
# 17   {'_id': 112, 'iso2': 'BY', 'iso3': 'BLR', 'lat...         0
# 18   {'_id': 56, 'iso2': 'BE', 'iso3': 'BEL', 'lat'...       723
# 19   {'_id': 84, 'iso2': 'BZ', 'iso3': 'BLZ', 'lat'...         4
# 20   {'_id': 204, 'iso2': 'BJ', 'iso3': 'BEN', 'lat...         0
# 21   {'_id': 60, 'iso2': 'BM', 'iso3': 'BMU', 'lat'...         1
# 22   {'_id': 64, 'iso2': 'BT', 'iso3': 'BTN', 'lat'...         0
# 23   {'_id': 68, 'iso2': 'BO', 'iso3': 'BOL', 'lat'...        71
# 24   {'_id': 70, 'iso2': 'BA', 'iso3': 'BIH', 'lat'...         0
# 25   {'_id': 72, 'iso2': 'BW', 'iso3': 'BWA', 'lat'...         1
# 26   {'_id': 76, 'iso2': 'BR', 'iso3': 'BRA', 'lat'...      8318
# 27   {'_id': 92, 'iso2': 'VG', 'iso3': 'VGB', 'lat'...         0
# 28   {'_id': 96, 'iso2': 'BN', 'iso3': 'BRN', 'lat'...         0
# 29   {'_id': 100, 'iso2': 'BG', 'iso3': 'BGR', 'lat...       523
# ..                                                 ...       ...
# 190  {'_id': 740, 'iso2': 'SR', 'iso3': 'SUR', 'lat...         2
# 191  {'_id': 748, 'iso2': 'SZ', 'iso3': 'SWZ', 'lat...        11
# 192  {'_id': 752, 'iso2': 'SE', 'iso3': 'SWE', 'lat...       249
# 193  {'_id': 756, 'iso2': 'CH', 'iso3': 'CHE', 'lat...       454
# 194  {'_id': 760, 'iso2': 'SY', 'iso3': 'SYR', 'lat...         0
# 195  {'_id': 158, 'iso2': 'TW', 'iso3': 'TWN', 'lat...         0
# 196  {'_id': 762, 'iso2': 'TJ', 'iso3': 'TJK', 'lat...         0
# 197  {'_id': 834, 'iso2': 'TZ', 'iso3': 'TZA', 'lat...         7
# 198  {'_id': 764, 'iso2': 'TH', 'iso3': 'THA', 'lat...         1
# 199  {'_id': 626, 'iso2': 'TL', 'iso3': 'TLS', 'lat...         0
# 200  {'_id': 768, 'iso2': 'TG', 'iso3': 'TGO', 'lat...         0
# 201  {'_id': 780, 'iso2': 'TT', 'iso3': 'TTO', 'lat...         2
# 202  {'_id': 788, 'iso2': 'TN', 'iso3': 'TUN', 'lat...       298
# 203  {'_id': 792, 'iso2': 'TR', 'iso3': 'TUR', 'lat...      5836
# 204  {'_id': 796, 'iso2': 'TC', 'iso3': 'TCA', 'lat...         1
# 205  {'_id': 784, 'iso2': 'AE', 'iso3': 'ARE', 'lat...         0
# 206  {'_id': 826, 'iso2': 'GB', 'iso3': 'GBR', 'lat...      1274
# 207  {'_id': 840, 'iso2': 'US', 'iso3': 'USA', 'lat...     26455
# 208  {'_id': 800, 'iso2': 'UG', 'iso3': 'UGA', 'lat...         0
# 209  {'_id': 804, 'iso2': 'UA', 'iso3': 'UKR', 'lat...       177
# 210  {'_id': 858, 'iso2': 'UY', 'iso3': 'URY', 'lat...        27
# 211  {'_id': 860, 'iso2': 'UZ', 'iso3': 'UZB', 'lat...       177
# 212  {'_id': 548, 'iso2': 'VU', 'iso3': 'VUT', 'lat...         0
# 213  {'_id': 862, 'iso2': 'VE', 'iso3': 'VEN', 'lat...       117
# 214  {'_id': 704, 'iso2': 'VN', 'iso3': 'VNM', 'lat...         0
# 215  {'_id': 876, 'iso2': 'WF', 'iso3': 'WLF', 'lat...         0
# 216  {'_id': 732, 'iso2': 'EH', 'iso3': 'ESH', 'lat...         0
# 217  {'_id': 887, 'iso2': 'YE', 'iso3': 'YEM', 'lat...         4
# 218  {'_id': 894, 'iso2': 'ZM', 'iso3': 'ZMB', 'lat...         0
# 219  {'_id': 716, 'iso2': 'ZW', 'iso3': 'ZWE', 'lat...         0
#
#      criticalPerOneMillion  deaths  ...  oneTestPerPeople  population  \
# 0                     2.37    1908  ...               243    39304797
# 1                    12.17     922  ...                14     2876418
# 2                     1.04    2527  ...                 0    44192535
# 3                   258.67      78  ...                 0       77319
# 4                     0.42     354  ...               194    33301496
# 5                     0.00       0  ...                 6       15061
# 6                    20.35       4  ...                20       98282
# 7                    82.05   39888  ...                11    45376124
# 8                     0.00    2372  ...                 6     2965667
# 9                    37.40      45  ...                 2      106964
# 10                    0.00     908  ...                 3    25628261
# 11                   68.23    3897  ...                 3     9028814
# 12                    0.00    1675  ...                 6    10178925
# 13                   27.86     163  ...                 9      394877
# 14                    6.37     341  ...                 1     1726659
# 15                    0.00    6906  ...                57   165402381
# 16                    3.48       7  ...                 6      287529
# 17                    0.00    1215  ...                 3     9447960
# 18                   62.27   17386  ...                 2    11611651
# 19                    9.98     176  ...                 9      400741
# 20                    0.00      44  ...                35    12259052
# 21                   16.08       9  ...                 1       62177
# 22                    0.00       0  ...                 4      775297
# 23                    6.05    8997  ...                32    11741980
# 24                    0.00    3012  ...                 7     3271828
# 25                    0.42      36  ...                 5     2372062
# 26                   39.01  177388  ...                 8   213217698
# 27                    0.00       1  ...                 5       30319
# 28                    0.00       3  ...                 6      439300
# 29                   75.52    5010  ...                 7     6925376
# ..                     ...     ...  ...               ...         ...
# 190                   3.40     117  ...                26      588918
# 191                   9.44     123  ...                18     1165382
# 192                  24.59    7067  ...                 3    10126722
# 193                  52.29    5495  ...                 3     8682191
# 194                   0.00     452  ...                 0    17682886
# 195                   0.00       7  ...               211    23835642
# 196                   0.00      87  ...                 0     9629636
# 197                   0.12      21  ...                 0    60460460
# 198                   0.01      60  ...                71    69876590
# 199                   0.00       0  ...                89     1329264
# 200                   0.00      65  ...                54     8361963
# 201                   1.43     122  ...                37     1401469
# 202                  25.10    3596  ...                24    11872334
# 203                  68.88   15103  ...                 4    84733150
# 204                  25.68       6  ...                 4       38944
# 205                   0.00     596  ...                 1     9942229
# 206                  18.72   61434  ...                 1    68041627
# 207                  79.72  290474  ...                 2   331849210
# 208                   0.00     207  ...                72    46355657
# 209                   4.06   13928  ...                 9    43618024
# 210                   7.76      83  ...                 7     3478992
# 211                   5.26     611  ...                24    33679104
# 212                   0.00       0  ...                 0      310224
# 213                   4.12     924  ...                12    28400540
# 214                   0.00      35  ...                73    97719499
# 215                   0.00       0  ...                10       11152
# 216                   0.00       1  ...                 0      603632
# 217                   0.13     649  ...              1755    30108167
# 218                   0.00     364  ...                41    18603824
# 219                   0.00     294  ...                80    14956546
#
#      recovered  recoveredPerOneMillion      tests  testsPerOneMillion  \
# 0        38033                  967.64     161815                4117
# 1        22180                 7710.98     201572               70077
# 2        57648                 1304.47          0                   0
# 3         6293                81390.09     173151             2239437
# 4         8353                  250.83     171247                5142
# 5            3                  199.19       2651              176018
# 6          134                 1363.42       4927               50131
# 7      1300696                28664.77    4111139               90601
# 8       119147                40175.45     532527              179564
# 9         4801                44884.26      53107              496494
# 10       25646                 1000.69   10228773              399121
# 11      256811                28443.49    3262088              361298
# 12       90278                 8869.11    1847191              181472
# 13        6003                15202.20      44757              113344
# 14       86215                49931.69    2129571             1233348
# 15      401194                 2425.56    2894622               17500
# 16         260                  904.26      49757              173050
# 17      126084                13345.10    3449089              365062
# 18       39938                 3439.48    6116392              526746
# 19        3943                 9839.27      44051              109924
# 20        2922                  238.35     353070               28801
# 21         222                 3570.45     113328             1822668
# 22         390                  503.03     210037              270912
# 23      124981                10643.95     369436               31463
# 24       59488                18181.88     439811              134424
# 25        9400                 3962.80     455040              191833
# 26     5801067                27207.25   25700000              120534
# 27          71                 2341.77       6431              212111
# 28         147                  334.62      77829              177166
# 29       65616                 9474.72    1023067              147727
# ..         ...                     ...        ...                 ...
# 190       5214                 8853.52      22231               37749
# 191       6094                 5229.19      63144               54183
# 192          0                    0.00    3457247              341398
# 193     279900                32238.41    2896303              333591
# 194       4000                  226.21          0                   0
# 195        582                   24.42     112939                4738
# 196      11881                 1233.80          0                   0
# 197        183                    3.03          0                   0
# 198       3874                   55.44     977854               13994
# 199         30                   22.57      14932               11233
# 200       2677                  320.14     155211               18562
# 201       5962                 4254.11      37523               26774
# 202      77798                 6552.88     486415               40970
# 203     436270                 5148.75   19888747              234722
# 204        740                19001.64       9247              237444
# 205     160295                16122.64   17649380             1775193
# 206          0                    0.00   45826753              673511
# 207    8983641                27071.46  209499273              631309
# 208       9374                  202.22     647471               13967
# 209     436564                10008.80    4838979              110940
# 210       5240                 1506.18     472299              135757
# 211      71482                 2122.44    1377915               40913
# 212          1                    3.22          0                   0
# 213      99982                 3520.43    2325906               81897
# 214       1224                   12.53    1339465               13707
# 215          1                   89.67       1149              103031
# 216          8                   13.25          0                   0
# 217       1554                   51.61      17157                 570
# 218      17211                  925.13     450333               24206
# 219       8972                  599.87     187667               12547
#
#      todayCases  todayDeaths  todayRecovered        updated
# 0           227            6              49  1607423908204
# 1             0            0               0  1607423908205
# 2             0            0               0  1607423908128
# 3             0            0               0  1607423908490
# 4             0            0               0  1607423908304
# 5             1            0               0  1607423908793
# 6             0            0               0  1607423908700
# 7             0            0               0  1607423907924
# 8           584           28            1498  1607423908102
# 9             0            0               0  1607423908516
# 10           15            0               4  1607423908218
# 11            0            0               0  1607423908028
# 12            0            0               0  1607423908041
# 13            0            0               0  1607423908432
# 14            0            0               0  1607423908131
# 15         2202           32            2571  1607423908019
# 16            0            0               0  1607423908693
# 17            0            0               0  1607423908044
# 18          859           66             671  1607423907937
# 19            0            0               0  1607423908431
# 20            0            0               0  1607423908595
# 21            0            0               0  1607423908691
# 22            2            0               2  1607423908687
# 23           97            2             182  1607423908096
# 24            0            0               0  1607423908126
# 25            0            0               0  1607423908400
# 26            0            0               0  1607423907916
# 27            0            0               0  1607423908706
# 28            1            0               0  1607423908698
# 29            0            0               0  1607423908038
# ..          ...          ...             ...            ...
# 190           0            0               0  1607423908506
# 191           0            0               0  1607423908494
# 192           0            0               0  1607423908029
# 193           0            0               0  1607423908025
# 194           0            0               0  1607423908428
# 195           2            0               8  1607423908618
# 196           0            0               0  1607423908387
# 197           0            0               0  1607423908630
# 198          19            0               6  1607423908519
# 199           0            0               0  1607423908714
# 200           0            0               0  1607423908590
# 201           0            0               0  1607423908493
# 202           0            0               0  1607423908123
# 203           0            0               0  1607423907933
# 204           0            0               0  1607423908616
# 205        1260            2             584  1607423908036
# 206           0            0               0  1607423907921
# 207           0            0               0  1607423907912
# 208           0            0               0  1607423908220
# 209       10811          195           12860  1607423907934
# 210           0            0               0  1607423908488
# 211         153            0             167  1607423908192
# 212           0            0               0  1607423908800
# 213           0            0               0  1607423908121
# 214           0            0               0  1607423908610
# 215           0            0               0  1607423908797
# 216           0            0               0  1607423908791
# 217           0            0               0  1607423908599
# 218           0            0               0  1607423908291
# 219           0            0               0  1607423908405
#
# [220 rows x 23 columns]

# %%
df[df.country=='Thailand']
#Italy USA
# Out:
#      active  activePerOneMillion  cases  casesPerOneMillion continent  \
# 198     192                 2.75   4126                  59      Asia
#
#       country                                        countryInfo  critical  \
# 198  Thailand  {'_id': 764, 'iso2': 'TH', 'iso3': 'THA', 'lat...         1
#
#      criticalPerOneMillion  deaths  ...  oneTestPerPeople  population  \
# 198                   0.01      60  ...                71    69876590
#
#      recovered  recoveredPerOneMillion   tests  testsPerOneMillion  \
# 198       3874                   55.44  977854               13994
#
#      todayCases  todayDeaths  todayRecovered        updated
# 198          19            0               6  1607423908519
#
# [1 rows x 23 columns]

# %%
# country='italy'
country='thailand'

url=f'https://disease.sh/v3/covid-19/countries/{country}'
r=requests.get(url)
j=r.json()
j
# Out:
# {'updated': 1607423908519,
#  'country': 'Thailand',
#  'countryInfo': {'_id': 764,
#   'iso2': 'TH',
#   'iso3': 'THA',
#   'lat': 15,
#   'long': 100,
#   'flag': 'https://disease.sh/assets/img/flags/th.png'},
#  'cases': 4126,
#  'todayCases': 19,
#  'deaths': 60,
#  'todayDeaths': 0,
#  'recovered': 3874,
#  'todayRecovered': 6,
#  'active': 192,
#  'critical': 1,
#  'casesPerOneMillion': 59,
#  'deathsPerOneMillion': 0.9,
#  'tests': 977854,
#  'testsPerOneMillion': 13994,
#  'population': 69876590,
#  'continent': 'Asia',
#  'oneCasePerPeople': 16936,
#  'oneDeathPerPeople': 1164610,
#  'oneTestPerPeople': 71,
#  'activePerOneMillion': 2.75,
#  'recoveredPerOneMillion': 55.44,
#  'criticalPerOneMillion': 0.01}

# %%
j['cases']
# Out:
# 4126

# %%
j['casesPerOneMillion']
# Out:
# 59

# %%
df=pd.DataFrame(j)
df
# Out:
#             updated   country                                 countryInfo  \
# _id   1607423908519  Thailand                                         764
# flag  1607423908519  Thailand  https://disease.sh/assets/img/flags/th.png
# iso2  1607423908519  Thailand                                          TH
# iso3  1607423908519  Thailand                                         THA
# lat   1607423908519  Thailand                                          15
# long  1607423908519  Thailand                                         100
#
#       cases  todayCases  deaths  todayDeaths  recovered  todayRecovered  \
# _id    4126          19      60            0       3874               6
# flag   4126          19      60            0       3874               6
# iso2   4126          19      60            0       3874               6
# iso3   4126          19      60            0       3874               6
# lat    4126          19      60            0       3874               6
# long   4126          19      60            0       3874               6
#
#       active  ...   tests  testsPerOneMillion  population  continent  \
# _id      192  ...  977854               13994    69876590       Asia
# flag     192  ...  977854               13994    69876590       Asia
# iso2     192  ...  977854               13994    69876590       Asia
# iso3     192  ...  977854               13994    69876590       Asia
# lat      192  ...  977854               13994    69876590       Asia
# long     192  ...  977854               13994    69876590       Asia
#
#       oneCasePerPeople  oneDeathPerPeople oneTestPerPeople  \
# _id              16936            1164610               71
# flag             16936            1164610               71
# iso2             16936            1164610               71
# iso3             16936            1164610               71
# lat              16936            1164610               71
# long             16936            1164610               71
#
#       activePerOneMillion  recoveredPerOneMillion  criticalPerOneMillion
# _id                  2.75                   55.44                   0.01
# flag                 2.75                   55.44                   0.01
# iso2                 2.75                   55.44                   0.01
# iso3                 2.75                   55.44                   0.01
# lat                  2.75                   55.44                   0.01
# long                 2.75                   55.44                   0.01
#
# [6 rows x 23 columns]

# %%
df.to_csv('covid19_latest.csv', index=False)

# %%
df.to_excel('covid19_latest.xlsx', index=False)
