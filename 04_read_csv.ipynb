# %% [markdown]
# ##  Read .CSV file
# #### CSV (Comma-Separated Value) คือ Text File สำหรับเก็บข้อมูลแบบตาราง
# #### โดยใช้จุลภาค (,) แบ่งข้อมูลในแต่ละหลัก (Column) และใช้การเว้นบรรทัดแทนการแบ่งแถว (Row)

# %% [markdown]
# ## Read a single CSV file

# %%
import pandas as pd

# %%
#https://github.com/mathawanup/learn_dataset/tree/master/eod
url = 'https://raw.githubusercontent.com/mathawanup/learn_dataset/master/eod/bbl.csv' # End Of Day stock price of  bbl
bbl=pd.read_csv(url) # raw data url 
bbl
# Out:
#          Date   Open   High    Low  Close   Adj Close     Volume
# 0  2017-02-01  174.5  175.5  173.5  175.5  169.355362  5953500.0
# 1  2017-02-02  175.0  177.0  174.5  175.5  169.355362  5250500.0
# 2  2017-02-03  175.0  178.5  175.0  178.5  172.250336  5470600.0
# 3  2017-02-06  178.5  181.5  178.5  180.5  174.180313  8150800.0
# 4  2017-02-07  180.5  181.0  179.0  180.0  173.697815  3648600.0
# 5  2017-02-08  180.0  180.0  178.5  179.0  172.732819  2574200.0
# 6  2017-02-09  179.5  182.5  179.5  181.0  174.662796  7290700.0
# 7  2017-02-10  182.0  182.5  181.0  182.5  176.110275  3589100.0
# 8  2017-02-13  182.5  182.5  182.5  182.5  176.110275        0.0
# 9  2017-02-14  182.0  182.5  179.0  179.0  172.732819  2841700.0

# %%
bbl.info() #แสดงรายละเอียดของ dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
# Date         10 non-null object
# Open         10 non-null float64
# High         10 non-null float64
# Low          10 non-null float64
# Close        10 non-null float64
# Adj Close    10 non-null float64
# Volume       10 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 688.0+ bytes

# %%
bbl=pd.read_csv(url,parse_dates=True, index_col='Date') #  parse_dates

# %%
bbl.info() #แสดงรายละเอียดของ dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2017-02-01 to 2017-02-14
# Data columns (total 6 columns):
# Open         10 non-null float64
# High         10 non-null float64
# Low          10 non-null float64
# Close        10 non-null float64
# Adj Close    10 non-null float64
# Volume       10 non-null float64
# dtypes: float64(6)
# memory usage: 560.0 bytes

# %% [markdown]
# ## read multiple csv files

# %%
#https://github.com/mathawanup/learn_dataset/tree/master/eod
stocks = ['bbl', 'ktb', 'scb'] 
dfs = [] 
location_prefix = 'https://github.com/mathawanup/learn_dataset/raw/master/eod/'

# %%
dfs = [pd.read_csv(f'{location_prefix}{s}.csv', parse_dates=True, index_col='Date') for s in stocks]

# %%
type(dfs)
# Out:
# list

# %%
dfs[0]
# Out:
#              Open   High    Low  Close   Adj Close     Volume
# Date
# 2017-02-01  174.5  175.5  173.5  175.5  169.355362  5953500.0
# 2017-02-02  175.0  177.0  174.5  175.5  169.355362  5250500.0
# 2017-02-03  175.0  178.5  175.0  178.5  172.250336  5470600.0
# 2017-02-06  178.5  181.5  178.5  180.5  174.180313  8150800.0
# 2017-02-07  180.5  181.0  179.0  180.0  173.697815  3648600.0
# 2017-02-08  180.0  180.0  178.5  179.0  172.732819  2574200.0
# 2017-02-09  179.5  182.5  179.5  181.0  174.662796  7290700.0
# 2017-02-10  182.0  182.5  181.0  182.5  176.110275  3589100.0
# 2017-02-13  182.5  182.5  182.5  182.5  176.110275        0.0
# 2017-02-14  182.0  182.5  179.0  179.0  172.732819  2841700.0

# %%
df = pd.concat(dfs, keys = stocks) 
df
# Out:
#                       Open        High         Low       Close   Adj Close  \
#     Date
# bbl 2017-02-01  174.500000  175.500000  173.500000  175.500000  169.355362
#     2017-02-02  175.000000  177.000000  174.500000  175.500000  169.355362
#     2017-02-03  175.000000  178.500000  175.000000  178.500000  172.250336
#     2017-02-06  178.500000  181.500000  178.500000  180.500000  174.180313
#     2017-02-07  180.500000  181.000000  179.000000  180.000000  173.697815
#     2017-02-08  180.000000  180.000000  178.500000  179.000000  172.732819
#     2017-02-09  179.500000  182.500000  179.500000  181.000000  174.662796
#     2017-02-10  182.000000  182.500000  181.000000  182.500000  176.110275
#     2017-02-13  182.500000  182.500000  182.500000  182.500000  176.110275
#     2017-02-14  182.000000  182.500000  179.000000  179.000000  172.732819
# ktb 2017-02-01   19.000000   19.200001   18.900000   19.200001   18.366062
# ...

# %%
df.index
# Out:
# MultiIndex([('bbl', '2017-02-01'),
#             ('bbl', '2017-02-02'),
#             ('bbl', '2017-02-03'),
#             ('bbl', '2017-02-06'),
#             ('bbl', '2017-02-07'),
#             ('bbl', '2017-02-08'),
#             ('bbl', '2017-02-09'),
#             ('bbl', '2017-02-10'),
#             ('bbl', '2017-02-13'),
#             ('bbl', '2017-02-14'),
#             ('ktb', '2017-02-01'),
#             ('ktb', '2017-02-02'),
#             ('ktb', '2017-02-03'),
#             ('ktb', '2017-02-06'),
#             ('ktb', '2017-02-07'),
#             ('ktb', '2017-02-08'),
#             ('ktb', '2017-02-09'),
#             ('ktb', '2017-02-10'),
#             ('ktb', '2017-02-13'),
#             ('ktb', '2017-02-14'),
#             ('scb', '2017-02-01'),
#             ('scb', '2017-02-02'),
#             ('scb', '2017-02-03'),
#             ('scb', '2017-02-06'),
#             ('scb', '2017-02-07'),
#             ('scb', '2017-02-08'),
#             ('scb', '2017-02-09'),
# ...

# %%
df.loc['scb']
# Out:
#              Open   High    Low  Close   Adj Close     Volume
# Date
# 2017-02-01  150.5  153.0  150.5  152.0  146.727814  6969200.0
# 2017-02-02  152.0  153.0  151.0  151.0  145.762512  6529100.0
# 2017-02-03  151.0  153.5  151.0  153.0  147.693130  6597700.0
# 2017-02-06  154.0  155.0  153.5  154.5  149.141098  9901200.0
# 2017-02-07  154.5  155.0  153.5  154.0  148.658447  3802600.0
# 2017-02-08  153.5  154.5  153.0  154.0  148.658447  5747300.0
# 2017-02-09  154.5  156.0  153.5  154.0  148.658447  6157400.0
# 2017-02-10  154.5  155.0  154.0  154.0  148.658447  9620500.0
# 2017-02-13  154.0  154.0  154.0  154.0  148.658447        0.0
# 2017-02-14  155.0  156.0  153.0  154.0  148.658447  9754000.0

# %%
df.loc['scb']['Close']
# Out:
# Date
# 2017-02-01    152.0
# 2017-02-02    151.0
# 2017-02-03    153.0
# 2017-02-06    154.5
# 2017-02-07    154.0
# 2017-02-08    154.0
# 2017-02-09    154.0
# 2017-02-10    154.0
# 2017-02-13    154.0
# 2017-02-14    154.0
# Name: Close, dtype: float64

# %%
# %matplotlib inline

# %%
df.loc['scb']['Close'].plot()
