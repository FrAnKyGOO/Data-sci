# %% [markdown]
# ### Time Series
# * data source https://stooq.com

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
df=pd.read_csv('https://github.com/mathawanup/learn_dataset/raw/master/%5Edji_m15_20.csv')
df
# Out:
#           Date      Open      High       Low     Close       Volume
# 0   2015-01-31  17823.07  17951.78  17136.30  17164.95   2173202910
# 1   2015-02-28  17169.99  18244.38  17037.76  18132.70   1751218583
# 2   2015-03-31  18134.05  18288.63  17579.27  17776.12   2470682017
# 3   2015-04-30  17778.52  18175.56  17585.01  17840.52   2175272088
# 4   2015-05-31  17859.27  18351.36  17733.12  18010.68   1832309213
# ..         ...       ...       ...       ...       ...          ...
# 68  2020-09-30  28439.61  29199.35  26537.01  27781.70  11075015810
# 69  2020-10-31  27940.63  28957.90  26143.77  26501.60   9685912322
# 70  2020-11-30  26691.28  30116.51  26691.28  29638.64   9628608626
# 71  2020-12-31  29797.50  30637.47  29599.29  30606.48   9698038696
# 72  2021-01-31  30627.47  31272.22  29856.30  29982.62   9455178658
#
# [73 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    73 non-null     object
#  1   Open    73 non-null     float64
#  2   High    73 non-null     float64
#  3   Low     73 non-null     float64
#  4   Close   73 non-null     float64
#  5   Volume  73 non-null     int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 3.5+ KB

# %%
df=pd.read_csv('https://github.com/mathawanup/learn_dataset/raw/master/%5Edji_m15_20.csv',parse_dates=['Date'],index_col='Date')
df
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 2015-01-31  17823.07  17951.78  17136.30  17164.95   2173202910
# 2015-02-28  17169.99  18244.38  17037.76  18132.70   1751218583
# 2015-03-31  18134.05  18288.63  17579.27  17776.12   2470682017
# 2015-04-30  17778.52  18175.56  17585.01  17840.52   2175272088
# 2015-05-31  17859.27  18351.36  17733.12  18010.68   1832309213
# ...              ...       ...       ...       ...          ...
# 2020-09-30  28439.61  29199.35  26537.01  27781.70  11075015810
# 2020-10-31  27940.63  28957.90  26143.77  26501.60   9685912322
# 2020-11-30  26691.28  30116.51  26691.28  29638.64   9628608626
# 2020-12-31  29797.50  30637.47  29599.29  30606.48   9698038696
# 2021-01-31  30627.47  31272.22  29856.30  29982.62   9455178658
#
# [73 rows x 5 columns]

# %%
sns.lineplot(x=df.index,y=df['Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
sns.lineplot(x=df.index, y=df['Open'],label='Open')
sns.lineplot(x=df.index, y=df['Close'],label='Close')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
sns.lineplot(x=df.index, y=df['Open'],label='Open')
sns.lineplot(x=df.index, y=df['Close'],label='Close')
plt.ylabel('colse-open index ') # ylabe
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
df=pd.read_csv('https://stooq.com/q/d/l/?s=^dji&d1=19000101&d2=20210131&i=m',
               parse_dates=['Date'], index_col='Date')
df.head()
# Out:
#              Open   High    Low  Close  Volume
# Date
# 1900-01-31  49.34  49.34  45.82  47.89     NaN
# 1900-02-28  48.77  49.51  45.88  46.32     NaN
# 1900-03-31  46.05  47.36  44.26  47.36     NaN
# 1900-04-30  47.47  47.91  44.32  44.42     NaN
# 1900-05-31  44.41  44.41  41.01  42.80     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1449 entries, 1900-01-31 to 2021-01-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1449 non-null   float64
#  1   High    1449 non-null   float64
#  2   Low     1449 non-null   float64
#  3   Close   1449 non-null   float64
#  4   Volume  1092 non-null   float64
# dtypes: float64(5)
# memory usage: 67.9 KB

# %%
sns.lineplot(x=df.index,y=df['Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.set(yscale='log')

sns.lineplot(x=df.index, y=df['Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.set(yscale='log')
sns.lineplot(x=df.index, y=df['Close'])
plt.title('Dow Jones Industrial')
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax2=ax.twinx()
ax2.set(yscale='log')

sns.lineplot(x=df.index, y=df['Close'],ax=ax,color='green',label='stadard',linewidth=.5)

sns.lineplot(x=df.index, y=df['Close'],ax=ax2,color='red',label='Log scale')

plt.title('Dow Jones Industrial')
plt.grid()
fig.legend()
